# %% [markdown]
# <a href="https://colab.research.google.com/github/JayZ6969/SIH-internal-2024/blob/main/AI_Based_Smart_Traffic_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# Clone YOLOv5 and Install Dependencies
# ```

# %%
# !git clone https://github.com/JayZ6969/SIH-internal-2024/  # clone
# %cd SIH-internal-2024/yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 2024-9-3 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.9/78.2 GB disk)

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')

# Copy the dataset into the YOLOv5 Folder
# !cp -r /content/drive/MyDrive/dataset/ /content/SIH-internal-2024/yolov5/dataset
# Out:
# Mounted at /content/drive

# %%
# !ls /content/SIH-internal-2024/yolov5/dataset/

# %%
# !python train.py --img 640 --batch 16 --epochs 16 --data /content/SIH-internal-2024/yolov5/dataset.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt --cache
# Out:
# 2024-09-03 14:53:33.715981: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-03 14:53:33.735727: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-03 14:53:33.742554: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 32 --data /content/SIH-internal-2024/yolov5/dataset.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#        0/31      3.56G    0.09244    0.04114    0.03645         63        640:  77%|███████▋  | 58/75 [00:22<00:07,  2.14it/s]/content/SIH-internal-2024/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/31      3.56G    0.09212    0.04093    0.03612         56        640:  79%|███████▊  | 59/75 [00:22<00:06,  2.39it/s]/content/SIH-internal-2024/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 16 --data /content/SIH-internal-2024/yolov5/dataset.yaml --cfg models/yolov5l.yaml --weights yolov5l.pt --cache
# Out:
# 2024-09-03 15:38:40.712159: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-03 15:38:40.733851: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-03 15:38:40.739875: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from IPython.display import Image, display

# Path to your image file
image_path = '/content/SIH-internal-2024/yolov5/runs/train/exp/results.png'

# Display the image
display(Image(filename=image_path))

# %%
from IPython.display import Image, display

# Path to your image file
image_path = '/content/SIH-internal-2024/yolov5/runs/train/exp2/results.png'

# Display the image
display(Image(filename=image_path))

# %%
from IPython.display import Image, display

# Path to your image file
image_path = '/content/SIH-internal-2024/yolov5/runs/train/exp4/results.png'

# Display the image
display(Image(filename=image_path))

# %%
# !zip -r /content/exp.zip /content/SIH-internal-2024/yolov5/runs/train/exp/
# Out:
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/ (stored 0%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/results.png (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/PR_curve.png (deflated 13%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/labels.jpg (deflated 22%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/val_batch2_pred.jpg (deflated 7%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/R_curve.png (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/train_batch2.jpg (deflated 4%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/train_batch1.jpg (deflated 4%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp/confusion_matrix.png (deflated 26%)
# ...

# %%
# !zip -r /content/exp2.zip /content/SIH-internal-2024/yolov5/runs/train/exp2/
# Out:
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/ (stored 0%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/results.png (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/PR_curve.png (deflated 11%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/hyp.yaml (deflated 45%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/labels.jpg (deflated 22%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/val_batch2_pred.jpg (deflated 7%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/R_curve.png (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/train_batch2.jpg (deflated 4%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/val_batch1_pred.jpg (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/train_batch1.jpg (deflated 4%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp2/confusion_matrix.png (deflated 25%)
# ...

# %%
# !zip -r /content/exp4.zip /content/SIH-internal-2024/yolov5/runs/train/exp4/
# Out:
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/ (stored 0%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/results.png (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/PR_curve.png (deflated 13%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/hyp.yaml (deflated 45%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/labels.jpg (deflated 22%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/val_batch2_pred.jpg (deflated 7%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/R_curve.png (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/train_batch2.jpg (deflated 4%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/val_batch1_pred.jpg (deflated 8%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/train_batch1.jpg (deflated 4%)
# updating: content/SIH-internal-2024/yolov5/runs/train/exp4/confusion_matrix.png (deflated 26%)
# ...

# %% [markdown]
# # Testing the model_1

# %%
# !python detect.py --weights /content/SIH-internal-2024/yolov5/runs/train/exp/weights/best.pt/ --img 640 --conf 0.25 --source /content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/ --save-txt --save-conf
# Out:
# detect: weights=['/content/SIH-internal-2024/yolov5/runs/train/exp/weights/best.pt/'], source=/content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2024-9-3 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/img1027.jpg: 640x640 1 Bus, 11.4ms
# ...

# %% [markdown]
# # Testing the model_2

# %%
# !python detect.py --weights /content/SIH-internal-2024/yolov5/runs/train/exp2/weights/best.pt/ --img 640 --conf 0.25 --source /content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/ --save-txt --save-conf
# Out:
# detect: weights=['/content/SIH-internal-2024/yolov5/runs/train/exp2/weights/best.pt/'], source=/content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2024-9-3 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/8 /content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/img1027.jpg: 640x640 1 Bus, 11.4ms
# ...

# %% [markdown]
# # Testing model_3

# %%
# !python detect.py --weights /content/SIH-internal-2024/yolov5/runs/train/exp4/weights/best.pt/ --img 640 --conf 0.25 --source /content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/ --save-txt --save-conf
# Out:
# detect: weights=['/content/SIH-internal-2024/yolov5/runs/train/exp4/weights/best.pt/'], source=/content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2024-9-3 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5l summary: 267 layers, 46129818 parameters, 0 gradients, 107.7 GFLOPs
# image 1/8 /content/SIH-internal-2024/yolov5/dataset/dataset-vehicles/images/test/img1027.jpg: 640x640 2 Buss, 47.4ms
# ...

# %%
# !zip -r /content/expdetect.zip /content/SIH-internal-2024/yolov5/runs/detect/exp/
# Out:
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/img1030.jpg (deflated 5%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/img1048.txt (deflated 55%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/img1037.txt (deflated 34%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/img1047.txt (deflated 19%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/img1030.txt (deflated 47%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/img1038.txt (deflated 34%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/img1040.txt (deflated 33%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/labels/img1027.txt (deflated 11%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp/img1047.jpg (deflated 6%)
# ...

# %%
# !zip -r /content/exp2detect.zip /content/SIH-internal-2024/yolov5/runs/detect/exp2/
# Out:
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/img1030.jpg (deflated 5%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/img1048.txt (deflated 42%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/img1037.txt (deflated 34%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/img1047.txt (deflated 11%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/img1030.txt (deflated 47%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/img1038.txt (deflated 34%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/img1028.txt (deflated 9%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp2/labels/img1040.txt (deflated 42%)
# ...

# %%
# !zip -r /content/exp3detect.zip /content/SIH-internal-2024/yolov5/runs/detect/exp3/
# Out:
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/img1030.jpg (deflated 5%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/img1048.txt (deflated 54%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/img1037.txt (deflated 9%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/img1047.txt (deflated 9%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/img1030.txt (deflated 43%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/img1038.txt (deflated 33%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/img1028.txt (deflated 17%)
#   adding: content/SIH-internal-2024/yolov5/runs/detect/exp3/labels/img1040.txt (deflated 33%)
# ...

# %%
# !zip -r /content/expweights.zip /content/SIH-internal-2024/yolov5/runs/train/exp/weights
# Out:
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp/weights/best.pt (deflated 9%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp/weights/last.pt (deflated 9%)

# %%
# !zip -r /content/exp2weights.zip /content/SIH-internal-2024/yolov5/runs/train/exp2/weights
# Out:
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp2/weights/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp2/weights/best.pt (deflated 9%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp2/weights/last.pt (deflated 9%)

# %%
# !zip -r /content/exp3weights.zip /content/SIH-internal-2024/yolov5/runs/train/exp3/weights
# Out:
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp3/weights/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp3/weights/best.pt (deflated 7%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp3/weights/last.pt (deflated 7%)

# %%
# !zip -r /content/exp4weights.zip /content/SIH-internal-2024/yolov5/runs/train/exp4/weights
# Out:
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp4/weights/ (stored 0%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp4/weights/best.pt (deflated 8%)
#   adding: content/SIH-internal-2024/yolov5/runs/train/exp4/weights/last.pt (deflated 8%)

# %%
from google.colab import files

# Download the zipped folders
files.download('/content/expweights.zip')
